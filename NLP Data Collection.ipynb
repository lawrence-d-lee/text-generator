# %%
import requests
from bs4 import BeautifulSoup
import json
import pandas as pd
import urllib
import time
import concurrent.futures
import random

# %%
def get_json(URL):
    page = requests.get(URL)
    soup = BeautifulSoup(page.content, "html.parser")
    relevant_part = soup.find_all("script")
    json_text = relevant_part[5].text.replace("window.jsonModel = ", "")
    required_json = json.loads(json_text)
    return required_json

# %%
def get_region_code(location):
    response = requests.get(
        "https://www.rightmove.co.uk/house-prices/" + location + ".html"
    )
    soup = BeautifulSoup(response.content, "html.parser")
    relevant_part = soup.find_all("script")[3]
    json_text = relevant_part.text.replace("window.__PRELOADED_STATE__ = ", "")
    required_json = json.loads(json_text)
    return required_json["searchLocation"]["locationId"]

# %%
def create_url(location, min_price ='', max_price = '', min_bedrooms='', max_bedrooms='', min_bathrooms='', max_bathrooms='', radius='', property_type='', index=''):
    base_url = "https://www.rightmove.co.uk/property-for-sale/find.html?"
    location_code = get_region_code(location)
    params = {'searchType': 'SALE', 'locationIdentifier': 'REGION^' + location_code, 
              "radius": radius, "minPrice":min_price,"maxPrice":max_price, 
              "minBedrooms":min_bedrooms, "maxBedrooms":max_bedrooms, 
              "minBathrooms":min_bathrooms, "maxBathrooms":'', "propertyTypes":property_type,
             "index":index}
    final_url = base_url + urllib.parse.urlencode(params)
    return final_url

# %%
get_json(create_url("manchester"))
# Out:
# {'properties': [{'id': 130152713,
#    'bedrooms': 4,
#    'bathrooms': 1,
#    'numberOfImages': 17,
#    'numberOfFloorplans': 0,
#    'numberOfVirtualTours': 1,
#    'summary': 'Normie & Company are pleased to bring to market this four bedroom detached property, which is ideally located close to Heaton Park, off Park Road.',
#    'displayAddress': 'Craigwell Road, Prestwich, M25',
#    'countryCode': 'GB',
#    'location': {'latitude': 53.523592, 'longitude': -2.254963},
#    'propertyImages': {'images': [{'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/40k/39452/130152713/39452_1db93034-608d-4238-8b2b-8c36fbd5134d_IMG_00_0000_max_476x317.jpeg',
#       'url': '40k/39452/130152713/39452_1db93034-608d-4238-8b2b-8c36fbd5134d_IMG_00_0000.jpeg',
#       'caption': None},
#      {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/40k/39452/130152713/39452_1db93034-608d-4238-8b2b-8c36fbd5134d_IMG_01_0000_max_476x317.jpeg',
#       'url': '40k/39452/130152713/39452_1db93034-608d-4238-8b2b-8c36fbd5134d_IMG_01_0000.jpeg',
#       'caption': 'Entrance Hallway'},
#      {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/40k/39452/130152713/39452_1db93034-608d-4238-8b2b-8c36fbd5134d_IMG_02_0000_max_476x317.jpeg',
#       'url': '40k/39452/130152713/39452_1db93034-608d-4238-8b2b-8c36fbd5134d_IMG_02_0000.jpeg',
#       'caption': 'Lounge'},
#      {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/40k/39452/130152713/39452_1db93034-608d-4238-8b2b-8c36fbd5134d_IMG_03_0000_max_476x317.jpeg',
#       'url': '40k/39452/130152713/39452_1db93034-608d-4238-8b2b-8c36fbd5134d_IMG_03_0000.jpeg',
#       'caption': None},
#      {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/40k/39452/130152713/39452_1db93034-608d-4238-8b2b-8c36fbd5134d_IMG_04_0000_max_476x317.jpeg',
#       'url': '40k/39452/130152713/39452_1db93034-608d-4238-8b2b-8c36fbd5134d_IMG_04_0000.jpeg',
#       'caption': 'Entrance Hallway'},
#      {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/40k/39452/130152713/39452_1db93034-608d-4238-8b2b-8c36fbd5134d_IMG_05_0000_max_476x317.jpeg',
#       'url': '40k/39452/130152713/39452_1db93034-608d-4238-8b2b-8c36fbd5134d_IMG_05_0000.jpeg',
#       'caption': 'Dining Room'},
#      {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/40k/39452/130152713/39452_1db93034-608d-4238-8b2b-8c36fbd5134d_IMG_06_0000_max_476x317.jpeg',
#       'url': '40k/39452/130152713/39452_1db93034-608d-4238-8b2b-8c36fbd5134d_IMG_06_0000.jpeg',
#       'caption': 'Conservatory'},
#      {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/40k/39452/130152713/39452_1db93034-608d-4238-8b2b-8c36fbd5134d_IMG_07_0000_max_476x317.jpeg',
#       'url': '40k/39452/130152713/39452_1db93034-608d-4238-8b2b-8c36fbd5134d_IMG_07_0000.jpeg',
#       'caption': 'Dining Room'},
#      {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/40k/39452/130152713/39452_1db93034-608d-4238-8b2b-8c36fbd5134d_IMG_08_0000_max_476x317.jpeg',
#       'url': '40k/39452/130152713/39452_1db93034-608d-4238-8b2b-8c36fbd5134d_IMG_08_0000.jpeg',
#       'caption': 'Kitchen'},
#      {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/40k/39452/130152713/39452_1db93034-608d-4238-8b2b-8c36fbd5134d_IMG_09_0000_max_476x317.jpeg',
#       'url': '40k/39452/130152713/39452_1db93034-608d-4238-8b2b-8c36fbd5134d_IMG_09_0000.jpeg',
#       'caption': 'Kitchen'},
#      {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/40k/39452/130152713/39452_1db93034-608d-4238-8b2b-8c36fbd5134d_IMG_10_0000_max_476x317.jpeg',
#       'url': '40k/39452/130152713/39452_1db93034-608d-4238-8b2b-8c36fbd5134d_IMG_10_0000.jpeg',
#       'caption': 'Utility Room'},
#      {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/40k/39452/130152713/39452_1db93034-608d-4238-8b2b-8c36fbd5134d_IMG_11_0000_max_476x317.jpeg',
#       'url': '40k/39452/130152713/39452_1db93034-608d-4238-8b2b-8c36fbd5134d_IMG_11_0000.jpeg',
#       'caption': 'Landing'},
#      {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/40k/39452/130152713/39452_1db93034-608d-4238-8b2b-8c36fbd5134d_IMG_12_0000_max_476x317.jpeg',
#       'url': '40k/39452/130152713/39452_1db93034-608d-4238-8b2b-8c36fbd5134d_IMG_12_0000.jpeg',
#       'caption': 'Master Bedroom'},
#      {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/40k/39452/130152713/39452_1db93034-608d-4238-8b2b-8c36fbd5134d_IMG_13_0000_max_476x317.jpeg',
#       'url': '40k/39452/130152713/39452_1db93034-608d-4238-8b2b-8c36fbd5134d_IMG_13_0000.jpeg',
#       'caption': 'Bedroom Two'},
#      {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/40k/39452/130152713/39452_1db93034-608d-4238-8b2b-8c36fbd5134d_IMG_14_0000_max_476x317.jpeg',
#       'url': '40k/39452/130152713/39452_1db93034-608d-4238-8b2b-8c36fbd5134d_IMG_14_0000.jpeg',
#       'caption': 'Bedroom Three'},
#      {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/40k/39452/130152713/39452_1db93034-608d-4238-8b2b-8c36fbd5134d_IMG_15_0000_max_476x317.jpeg',
#       'url': '40k/39452/130152713/39452_1db93034-608d-4238-8b2b-8c36fbd5134d_IMG_15_0000.jpeg',
#       'caption': 'Bathroom'},
#      {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/40k/39452/130152713/39452_1db93034-608d-4238-8b2b-8c36fbd5134d_IMG_16_0000_max_476x317.jpeg',
#       'url': '40k/39452/130152713/39452_1db93034-608d-4238-8b2b-8c36fbd5134d_IMG_16_0000.jpeg',
#       'caption': 'Sep. Wc.,'}],
#     'mainImageSrc': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/40k/39452/130152713/39452_1db93034-608d-4238-8b2b-8c36fbd5134d_IMG_00_0000_max_476x317.jpeg',
#     'mainMapImageSrc': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/40k/39452/130152713/39452_1db93034-608d-4238-8b2b-8c36fbd5134d_IMG_00_0000_max_296x197.jpeg'},
#    'propertySubType': 'Detached',
#    'listingUpdate': {'listingUpdateReason': 'price_reduced',
#     'listingUpdateDate': '2023-03-08T11:21:06Z'},
#    'premiumListing': False,
#    'featuredProperty': True,
#    'price': {'amount': 490000,
#     'frequency': 'not specified',
#     'currencyCode': 'GBP',
#     'displayPrices': [{'displayPrice': '£490,000',
#       'displayPriceQualifier': ''}]},
#    'customer': {'branchId': 39452,
#     'brandPlusLogoURI': '/company/clogo_rmchoice_15632_0005.png',
#     'contactTelephone': '020 3834 7844',
#     'branchDisplayName': 'Normie & Co, Prestwich',
#     'branchName': 'Prestwich',
#     'brandTradingName': 'Normie & Co',
#     'branchLandingPageUrl': '/estate-agents/agent/Normie-and-Co/Prestwich-39452.html',
#     'development': False,
#     'showReducedProperties': True,
#     'commercial': False,
#     'showOnMap': True,
#     'enhancedListing': False,
#     'developmentContent': None,
#     'buildToRent': False,
#     'buildToRentBenefits': [],
#     'brandPlusLogoUrl': 'https://media.rightmove.co.uk:443/dir/company/clogo_rmchoice_15632_0005_max_100x50.png'},
#    'distance': None,
#    'transactionType': 'buy',
#    'productLabel': {'productLabelText': '', 'spotlightLabel': False},
#    'commercial': False,
#    'development': False,
#    'residential': True,
#    'students': False,
#    'auction': False,
#    'feesApply': False,
#    'feesApplyText': None,
#    'displaySize': '',
#    'showOnMap': True,
#    'propertyUrl': '/properties/130152713#/?channel=RES_BUY',
#    'contactUrl': '/property-for-sale/contactBranch.html?propertyId=130152713',
#    'staticMapUrl': None,
#    'channel': 'BUY',
#    'firstVisibleDate': '2022-12-21T16:31:07Z',
#    'keywords': [],
#    'keywordMatchType': 'no_keyword',
#    'saved': False,
#    'hidden': False,
#    'onlineViewingsAvailable': False,
#    'lozengeModel': {'matchingLozenges': []},
#    'hasBrandPlus': True,
#    'displayStatus': '',
#    'enquiredTimestamp': None,
#    'isRecent': False,
#    'enhancedListing': False,
#    'addedOrReduced': 'Reduced on 08/03/2023',
#    'formattedBranchName': ' by Normie & Co, Prestwich',
#    'formattedDistance': '',
#    'heading': 'Featured Property',
#    'propertyTypeFullDescription': '4 bedroom detached house for sale'},
#   {'id': 132187142,
#    'bedrooms': 0,
#    'bathrooms': None,
#    'numberOfImages': 1,
#    'numberOfFloorplans': 0,
#    'numberOfVirtualTours': 0,
#    'summary': 'OFF MARKET BUILDINGS AVAILABLE, PRICES FROM £4,000,0000 - £13,000,000 WITH YIELDS FROM 7%.',
#    'displayAddress': 'Manchester, Greater Manchester, M3',
#    'countryCode': 'GB',
#    'location': {'latitude': 53.47918, 'longitude': -2.25114},
#    'propertyImages': {'images': [{'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/234k/233348/132187142/233348_offmarketmanchester_IMG_00_0000_max_476x317.png',
#       'url': '234k/233348/132187142/233348_offmarketmanchester_IMG_00_0000.png',
#       'caption': None}],
#     'mainImageSrc': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/234k/233348/132187142/233348_offmarketmanchester_IMG_00_0000_max_476x317.png',
#     'mainMapImageSrc': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/234k/233348/132187142/233348_offmarketmanchester_IMG_00_0000_max_296x197.png'},
#    'propertySubType': 'Block of Apartments',
#    'listingUpdate': {'listingUpdateReason': 'new',
#     'listingUpdateDate': '2023-03-02T21:46:01Z'},
#    'premiumListing': False,
#    'featuredProperty': False,
#    'price': {'amount': 12900000,
#     'frequency': 'not specified',
#     'currencyCode': 'GBP',
#     'displayPrices': [{'displayPrice': '£12,900,000',
#       'displayPriceQualifier': ''}]},
#    'customer': {'branchId': 233348,
#     'brandPlusLogoURI': '/234k/233348/branch_logo_233348_9.png',
#     'contactTelephone': '0113 519 9539',
#     'branchDisplayName': 'Virtue Estate Agents, Leeds',
#     'branchName': 'Leeds',
#     'brandTradingName': 'Virtue Estate Agents',
#     'branchLandingPageUrl': '/estate-agents/agent/Virtue-Estate-Agents/Leeds-233348.html',
#     'development': False,
#     'showReducedProperties': True,
#     'commercial': False,
#     'showOnMap': True,
#     'enhancedListing': False,
#     'developmentContent': None,
#     'buildToRent': False,
#     'buildToRentBenefits': [],
#     'brandPlusLogoUrl': 'https://media.rightmove.co.uk:443/dir/234k/233348/branch_logo_233348_9_max_100x50.png'},
#    'distance': None,
#    'transactionType': 'buy',
#    'productLabel': {'productLabelText': '', 'spotlightLabel': False},
#    'commercial': False,
#    'development': True,
#    'residential': True,
#    'students': False,
#    'auction': False,
#    'feesApply': False,
#    'feesApplyText': None,
#    'displaySize': '',
#    'showOnMap': True,
#    'propertyUrl': '/properties/132187142#/?channel=RES_BUY',
#    'contactUrl': '/property-for-sale/contactBranch.html?propertyId=132187142',
#    'staticMapUrl': None,
#    'channel': 'BUY',
#    'firstVisibleDate': '2023-03-02T21:40:14Z',
#    'keywords': [],
#    'keywordMatchType': 'no_keyword',
#    'saved': False,
#    'hidden': False,
#    'onlineViewingsAvailable': False,
#    'lozengeModel': {'matchingLozenges': [{'type': 'NEW_HOME', 'priority': 3}]},
#    'hasBrandPlus': True,
#    'displayStatus': '',
#    'enquiredTimestamp': None,
#    'isRecent': False,
#    'enhancedListing': False,
#    'addedOrReduced': 'Added on 02/03/2023',
#    'formattedBranchName': ' by Virtue Estate Agents, Leeds',
#    'formattedDistance': '',
#    'heading': '',
#    'propertyTypeFullDescription': 'Block of apartments for sale'},
#   {'id': 131280641,
#    'bedrooms': 3,
#    'bathrooms': 3,
#    'numberOfImages': 12,
#    'numberOfFloorplans': 0,
#    'numberOfVirtualTours': 0,
#    'summary': 'This exquisite 3 bed duplex apartment situated on the 50th and 51st floors of the East Tower spans over 3,220 sq ft of carefully created living space and boats spectacular far-reaching views over the city and beyond',
#    'displayAddress': 'Owen Street,\r\nManchester,\r\nM15 4TN',
#    'countryCode': 'GB',
#    'location': {'latitude': 53.47217, 'longitude': -2.25155},
#    'propertyImages': {'images': [{'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/81k/80106/131280641/80106_B5004TG_IMG_12_0000_max_476x317.jpeg',
#       'url': '81k/80106/131280641/80106_B5004TG_IMG_12_0000.jpeg',
#       'caption': None},
#      {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/81k/80106/131280641/80106_B5004TG_IMG_02_0001_max_476x317.jpeg',
#       'url': '81k/80106/131280641/80106_B5004TG_IMG_02_0001.jpeg',
#       'caption': None},
#      {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/81k/80106/131280641/80106_B5004TG_IMG_11_0000_max_476x317.jpeg',
#       'url': '81k/80106/131280641/80106_B5004TG_IMG_11_0000.jpeg',
#       'caption': None},
#      {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/81k/80106/131280641/80106_B5004TG_IMG_00_0001_max_476x317.jpeg',
#       'url': '81k/80106/131280641/80106_B5004TG_IMG_00_0001.jpeg',
#       'caption': None},
#      {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/81k/80106/131280641/80106_B5004TG_IMG_01_0001_max_476x317.jpeg',
#       'url': '81k/80106/131280641/80106_B5004TG_IMG_01_0001.jpeg',
#       'caption': None},
#      {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/81k/80106/131280641/80106_B5004TG_IMG_04_0001_max_476x317.jpeg',
#       'url': '81k/80106/131280641/80106_B5004TG_IMG_04_0001.jpeg',
#       'caption': None},
#      {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/81k/80106/131280641/80106_B5004TG_IMG_05_0001_max_476x317.jpeg',
#       'url': '81k/80106/131280641/80106_B5004TG_IMG_05_0001.jpeg',
#       'caption': None},
#      {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/81k/80106/131280641/80106_B5004TG_IMG_06_0001_max_476x317.jpeg',
#       'url': '81k/80106/131280641/80106_B5004TG_IMG_06_0001.jpeg',
#       'caption': None},
#      {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/81k/80106/131280641/80106_B5004TG_IMG_07_0001_max_476x317.jpeg',
#       'url': '81k/80106/131280641/80106_B5004TG_IMG_07_0001.jpeg',
#       'caption': None},
#      {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/81k/80106/131280641/80106_B5004TG_IMG_08_0001_max_476x317.jpeg',
#       'url': '81k/80106/131280641/80106_B5004TG_IMG_08_0001.jpeg',
#       'caption': None},
#      {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/81k/80106/131280641/80106_B5004TG_IMG_09_0001_max_476x317.jpeg',
#       'url': '81k/80106/131280641/80106_B5004TG_IMG_09_0001.jpeg',
#       'caption': None},
#      {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/81k/80106/131280641/80106_B5004TG_IMG_10_0002_max_476x317.jpeg',
#       'url': '81k/80106/131280641/80106_B5004TG_IMG_10_0002.jpeg',
#       'caption': None}],
#     'mainImageSrc': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/81k/80106/131280641/80106_B5004TG_IMG_12_0000_max_476x317.jpeg',
#     'mainMapImageSrc': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/81k/80106/131280641/80106_B5004TG_IMG_12_0000_max_296x197.jpeg'},
#    'propertySubType': 'Penthouse',
#    'listingUpdate': {'listingUpdateReason': 'new',
#     'listingUpdateDate': '2023-02-01T10:50:06Z'},
#    'premiumListing': False,
#    'featuredProperty': False,
#    'price': {'amount': 2500000,
#     'frequency': 'not specified',
#     'currencyCode': 'GBP',
#     'displayPrices': [{'displayPrice': '£2,500,000',
#       'displayPriceQualifier': ''}]},
#    'customer': {'branchId': 80106,
#     'brandPlusLogoURI': '/81k/80106/branch_logo_80106_0000.jpeg',
#     'contactTelephone': '0161 524 6493',
#     'branchDisplayName': 'Renaker',
#     'branchName': 'Deansgate Square',
#     'brandTradingName': 'Renaker',
#     'branchLandingPageUrl': '/developer/branch/Renaker/Deansgate-Square-80106.html',
#     'development': True,
#     'showReducedProperties': True,
#     'commercial': False,
#     'showOnMap': True,
#     'enhancedListing': True,
#     'developmentContent': {'headline': ' Deansgate Square',
#      'features': ['Luxury living with unrivalled private on-site amenities',
#       'An iconic location',
#       'City centre living in Manchester',
#       'Enquire today!']},
#     'buildToRent': False,
#     'buildToRentBenefits': [],
#     'brandPlusLogoUrl': 'https://media.rightmove.co.uk:443/dir/81k/80106/branch_logo_80106_0000_max_100x50.jpeg'},
#    'distance': None,
#    'transactionType': 'buy',
#    'productLabel': {'productLabelText': 'Just Launched',
#     'spotlightLabel': True},
#    'commercial': False,
#    'development': True,
#    'residential': True,
#    'students': False,
#    'auction': False,
#    'feesApply': False,
#    'feesApplyText': None,
#    'displaySize': '3,228 sq. ft.',
#    'showOnMap': True,
#    'propertyUrl': '/properties/131280641#/?channel=RES_BUY',
#    'contactUrl': '/property-for-sale/contactBranch.html?propertyId=131280641',
#    'staticMapUrl': 'https://media.rightmove.co.uk:443/map/_generate?width=231&height=96&zoomLevel=11&latitude=53.47217&longitude=-2.25155&signature=uFTOccZ41DQT6eUwua8WGHcc2fo=',
#    'channel': 'BUY',
#    'firstVisibleDate': '2023-02-01T10:44:36Z',
#    'keywords': [],
#    'keywordMatchType': 'no_keyword',
#    'saved': False,
#    'hidden': False,
#    'onlineViewingsAvailable': False,
#    'lozengeModel': {'matchingLozenges': [{'type': 'NEW_HOME', 'priority': 3}]},
#    'hasBrandPlus': True,
#    'displayStatus': '',
#    'enquiredTimestamp': None,
#    'isRecent': False,
#    'enhancedListing': True,
#    'addedOrReduced': 'Added on 01/02/2023',
#    'formattedBranchName': ' by Renaker',
#    'formattedDistance': '',
#    'heading': '',
#    'propertyTypeFullDescription': '3 bedroom penthouse for sale'},
#   {'id': 132064937,
#    'bedrooms': 7,
#    'bathrooms': 6,
#    'numberOfImages': 13,
#    'numberOfFloorplans': 0,
#    'numberOfVirtualTours': 0,
#    'summary': 'A beautifully presented block of four apartments and commercial unit. Internally there is a communal hallway for the four apartments, the commercial unit has its own entrance close to the popular Burton Road. The whole development has been finished to an exceptionally high standard and would be a...',
#    'displayAddress': 'Burton Road, Manchester, M20',
#    'countryCode': 'GB',
#    'location': {'latitude': 53.43329, 'longitude': -2.23085},
#    'propertyImages': {'images': [{'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/1k/828/132064937/828_WIW220226_IMG_00_0000_max_476x317.jpeg',
#       'url': '1k/828/132064937/828_WIW220226_IMG_00_0000.jpeg',
#       'caption': 'Picture No. 01'},
#      {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/1k/828/132064937/828_WIW220226_IMG_01_0000_max_476x317.jpeg',
#       'url': '1k/828/132064937/828_WIW220226_IMG_01_0000.jpeg',
#       'caption': 'Picture No. 12'},
#      {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/1k/828/132064937/828_WIW220226_IMG_02_0000_max_476x317.jpeg',
#       'url': '1k/828/132064937/828_WIW220226_IMG_02_0000.jpeg',
#       'caption': 'Picture No. 06'},
#      {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/1k/828/132064937/828_WIW220226_IMG_03_0000_max_476x317.jpeg',
#       'url': '1k/828/132064937/828_WIW220226_IMG_03_0000.jpeg',
#       'caption': 'Picture No. 02'},
#      {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/1k/828/132064937/828_WIW220226_IMG_04_0000_max_476x317.jpeg',
#       'url': '1k/828/132064937/828_WIW220226_IMG_04_0000.jpeg',
#       'caption': 'Picture No. 04'},
#      {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/1k/828/132064937/828_WIW220226_IMG_05_0000_max_476x317.jpeg',
#       'url': '1k/828/132064937/828_WIW220226_IMG_05_0000.jpeg',
#       'caption': 'Picture No. 03'},
#      {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/1k/828/132064937/828_WIW220226_IMG_06_0000_max_476x317.jpeg',
#       'url': '1k/828/132064937/828_WIW220226_IMG_06_0000.jpeg',
#       'caption': 'Picture No. 07'},
#      {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/1k/828/132064937/828_WIW220226_IMG_07_0000_max_476x317.jpeg',
#       'url': '1k/828/132064937/828_WIW220226_IMG_07_0000.jpeg',
#       'caption': 'Picture No. 05'},
#      {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/1k/828/132064937/828_WIW220226_IMG_08_0000_max_476x317.jpeg',
#       'url': '1k/828/132064937/828_WIW220226_IMG_08_0000.jpeg',
#       'caption': 'Picture No. 08'},
#      {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/1k/828/132064937/828_WIW220226_IMG_09_0000_max_476x317.jpeg',
#       'url': '1k/828/132064937/828_WIW220226_IMG_09_0000.jpeg',
#       'caption': 'Picture No. 10'},
#      {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/1k/828/132064937/828_WIW220226_IMG_10_0000_max_476x317.jpeg',
#       'url': '1k/828/132064937/828_WIW220226_IMG_10_0000.jpeg',
#       'caption': 'Picture No. 11'},
#      {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/1k/828/132064937/828_WIW220226_IMG_11_0000_max_476x317.jpeg',
#       'url': '1k/828/132064937/828_WIW220226_IMG_11_0000.jpeg',
#       'caption': 'Picture No. 13'},
#      {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/1k/828/132064937/828_WIW220226_IMG_12_0000_max_476x317.jpeg',
#       'url': '1k/828/132064937/828_WIW220226_IMG_12_0000.jpeg',
#       'caption': 'Picture No. 14'}],
#     'mainImageSrc': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/1k/828/132064937/828_WIW220226_IMG_00_0000_max_476x317.jpeg',
#     'mainMapImageSrc': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/1k/828/132064937/828_WIW220226_IMG_00_0000_max_296x197.jpeg'},
#    'propertySubType': 'House',
#    'listingUpdate': {'listingUpdateReason': 'new',
#     'listingUpdateDate': '2023-02-27T22:21:01Z'},
#    'premiumListing': True,
#    'featuredProperty': False,
#    'price': {'amount': 2250000,
#     'frequency': 'not specified',
#     'currencyCode': 'GBP',
#     'displayPrices': [{'displayPrice': '£2,250,000',
#       'displayPriceQualifier': ''}]},
#    'customer': {'branchId': 828,
#     'brandPlusLogoURI': '/brand/brand_rmchoice_logo_10_0001.jpeg',
#     'contactTelephone': '0161 524 2534',
#     'branchDisplayName': 'Bridgfords, Withington',
#     'branchName': 'Withington',
#     'brandTradingName': 'Bridgfords',
#     'branchLandingPageUrl': '/estate-agents/agent/Bridgfords/Withington-828.html',
#     'development': False,
#     'showReducedProperties': True,
#     'commercial': False,
#     'showOnMap': True,
#     'enhancedListing': False,
#     'developmentContent': None,
#     'buildToRent': False,
#     'buildToRentBenefits': [],
#     'brandPlusLogoUrl': 'https://media.rightmove.co.uk:443/dir/brand/brand_rmchoice_logo_10_0001_max_100x50.jpeg'},
#    'distance': None,
#    'transactionType': 'buy',
#    'productLabel': {'productLabelText': 'Premium Listing',
#     'spotlightLabel': False},
#    'commercial': False,
#    'development': False,
#    'residential': True,
#    'students': False,
#    'auction': False,
#    'feesApply': False,
#    'feesApplyText': None,
#    'displaySize': '',
#    'showOnMap': True,
#    'propertyUrl': '/properties/132064937#/?channel=RES_BUY',
#    'contactUrl': '/property-for-sale/contactBranch.html?propertyId=132064937',
#    'staticMapUrl': None,
#    'channel': 'BUY',
#    'firstVisibleDate': '2023-02-27T22:15:19Z',
#    'keywords': [],
#    'keywordMatchType': 'no_keyword',
#    'saved': False,
#    'hidden': False,
#    'onlineViewingsAvailable': False,
#    'lozengeModel': {'matchingLozenges': []},
#    'hasBrandPlus': True,
#    'displayStatus': '',
#    'enquiredTimestamp': None,
#    'isRecent': False,
#    'enhancedListing': False,
#    'addedOrReduced': 'Added on 27/02/2023',
#    'formattedBranchName': ' by Bridgfords, Withington',
#    'formattedDistance': '',
#    'heading': '',
#    'propertyTypeFullDescription': '7 bedroom house for sale'},
#   {'id': 130980773,
#    'bedrooms': 6,
#    'bathrooms': 4,
#    'numberOfImages': 34,
#    'numberOfFloorplans': 2,
#    'numberOfVirtualTours': 0,
#    'summary': 'Wow.......Dunelm.........It truly is a hidden gem! Occupying a commanding yet concealed position just off the prestigious Chatsworth Road in Worsley. A simply outstanding detached family home which offers an abundance of space set over four floors. On a quiet no-through road from the moment you e...',
#    'displayAddress': 'Dunelm, Haddon Road, Worsley, Manchester',
#    'countryCode': 'GB',
#    'location': {'latitude': 53.50126, 'longitude': -2.356936},
#    'propertyImages': {'images': [{'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/146k/145505/130980773/145505_11832726_IMG_01_0000_max_476x317.jpeg',
#       'url': '146k/145505/130980773/145505_11832726_IMG_01_0000.jpeg',
#       'caption': 'View'},
#      {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/146k/145505/130980773/145505_11832726_IMG_02_0000_max_476x317.jpeg',
#       'url': '146k/145505/130980773/145505_11832726_IMG_02_0000.jpeg',
#       'caption': 'Aerial View'},
#      {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/146k/145505/130980773/145505_11832726_IMG_27_0000_max_476x317.jpeg',
#       'url': '146k/145505/130980773/145505_11832726_IMG_27_0000.jpeg',
#       'caption': 'Aerial View'},
#      {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/146k/145505/130980773/145505_11832726_IMG_28_0000_max_476x317.jpeg',
#       'url': '146k/145505/130980773/145505_11832726_IMG_28_0000.jpeg',
#       'caption': 'Architects Drawing'},
#      {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/146k/145505/130980773/145505_11832726_IMG_33_0000_max_476x317.jpeg',
#       'url': '146k/145505/130980773/145505_11832726_IMG_33_0000.jpeg',
#       'caption': 'Dunelm Elevation'},
#      {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/146k/145505/130980773/145505_11832726_IMG_34_0000_max_476x317.jpeg',
#       'url': '146k/145505/130980773/145505_11832726_IMG_34_0000.jpeg',
#       'caption': 'Elevations'},
#      {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/146k/145505/130980773/145505_11832726_IMG_35_0000_max_476x317.jpeg',
#       'url': '146k/145505/130980773/145505_11832726_IMG_35_0000.jpeg',
#       'caption': 'Concept Design'},
#      {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/146k/145505/130980773/145505_11832726_IMG_36_0000_max_476x317.jpeg',
#       'url': '146k/145505/130980773/145505_11832726_IMG_36_0000.jpeg',
#       'caption': 'Example Of Concept Design'},
#      {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/146k/145505/130980773/145505_11832726_IMG_37_0000_max_476x317.jpeg',
#       'url': '146k/145505/130980773/145505_11832726_IMG_37_0000.jpeg',
#       'caption': 'Example Of Concept Design'},
#      {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/146k/145505/130980773/145505_11832726_IMG_38_0000_max_476x317.jpeg',
#       'url': '146k/145505/130980773/145505_11832726_IMG_38_0000.jpeg',
#       'caption': 'Example Of Concept Design'},
#      {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/146k/145505/130980773/145505_11832726_IMG_03_0000_max_476x317.jpeg',
#       'url': '146k/145505/130980773/145505_11832726_IMG_03_0000.jpeg',
#       'caption': 'Hallway'},
#      {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/146k/145505/130980773/145505_11832726_IMG_06_0000_max_476x317.jpeg',
#       'url': '146k/145505/130980773/145505_11832726_IMG_06_0000.jpeg',
#       'caption': 'Entrance'},
#      {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/146k/145505/130980773/145505_11832726_IMG_07_0000_max_476x317.jpeg',
#       'url': '146k/145505/130980773/145505_11832726_IMG_07_0000.jpeg',
#       'caption': 'Reception Room'},
#      {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/146k/145505/130980773/145505_11832726_IMG_08_0000_max_476x317.jpeg',
#       'url': '146k/145505/130980773/145505_11832726_IMG_08_0000.jpeg',
#       'caption': 'Reception Room'},
#      {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/146k/145505/130980773/145505_11832726_IMG_09_0000_max_476x317.jpeg',
#       'url': '146k/145505/130980773/145505_11832726_IMG_09_0000.jpeg',
#       'caption': 'Fireplace'},
#      {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/146k/145505/130980773/145505_11832726_IMG_10_0000_max_476x317.jpeg',
#       'url': '146k/145505/130980773/145505_11832726_IMG_10_0000.jpeg',
#       'caption': 'Reception Room'},
#      {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/146k/145505/130980773/145505_11832726_IMG_11_0000_max_476x317.jpeg',
#       'url': '146k/145505/130980773/145505_11832726_IMG_11_0000.jpeg',
#       'caption': 'Fireplace'},
#      {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/146k/145505/130980773/145505_11832726_IMG_12_0000_max_476x317.jpeg',
#       'url': '146k/145505/130980773/145505_11832726_IMG_12_0000.jpeg',
#       'caption': 'Kitchen'},
#      {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/146k/145505/130980773/145505_11832726_IMG_13_0000_max_476x317.jpeg',
#       'url': '146k/145505/130980773/145505_11832726_IMG_13_0000.jpeg',
#       'caption': 'Guest WC'},
#      {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/146k/145505/130980773/145505_11832726_IMG_14_0000_max_476x317.jpeg',
#       'url': '146k/145505/130980773/145505_11832726_IMG_14_0000.jpeg',
#       'caption': 'Landing'},
#      {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/146k/145505/130980773/145505_11832726_IMG_15_0000_max_476x317.jpeg',
#       'url': '146k/145505/130980773/145505_11832726_IMG_15_0000.jpeg',
#       'caption': 'Landing'},
#      {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/146k/145505/130980773/145505_11832726_IMG_16_0000_max_476x317.jpeg',
#       'url': '146k/145505/130980773/145505_11832726_IMG_16_0000.jpeg',
#       'caption': 'Bedroom'},
#      {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/146k/145505/130980773/145505_11832726_IMG_18_0000_max_476x317.jpeg',
#       'url': '146k/145505/130980773/145505_11832726_IMG_18_0000.jpeg',
#       'caption': 'Bedroom'},
#      {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/146k/145505/130980773/145505_11832726_IMG_19_0000_max_476x317.jpeg',
#       'url': '146k/145505/130980773/145505_11832726_IMG_19_0000.jpeg',
#       'caption': 'Bedroom'},
#      {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/146k/145505/130980773/145505_11832726_IMG_20_0000_max_476x317.jpeg',
#       'url': '146k/145505/130980773/145505_11832726_IMG_20_0000.jpeg',
#       'caption': 'Bedroom'},
#      {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/146k/145505/130980773/145505_11832726_IMG_21_0000_max_476x317.jpeg',
#       'url': '146k/145505/130980773/145505_11832726_IMG_21_0000.jpeg',
#       'caption': 'Shower Room'},
#      {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/146k/145505/130980773/145505_11832726_IMG_22_0000_max_476x317.jpeg',
#       'url': '146k/145505/130980773/145505_11832726_IMG_22_0000.jpeg',
#       'caption': 'Bedroom'},
#      {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/146k/145505/130980773/145505_11832726_IMG_23_0000_max_476x317.jpeg',
#       'url': '146k/145505/130980773/145505_11832726_IMG_23_0000.jpeg',
#       'caption': 'Golf Course View'},
#      {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/146k/145505/130980773/145505_11832726_IMG_24_0000_max_476x317.jpeg',
#       'url': '146k/145505/130980773/145505_11832726_IMG_24_0000.jpeg',
#       'caption': 'Front'},
#      {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/146k/145505/130980773/145505_11832726_IMG_26_0000_max_476x317.jpeg',
#       'url': '146k/145505/130980773/145505_11832726_IMG_26_0000.jpeg',
#       'caption': 'Entrance'},
#      {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/146k/145505/130980773/145505_11832726_IMG_29_0000_max_476x317.jpeg',
#       'url': '146k/145505/130980773/145505_11832726_IMG_29_0000.jpeg',
#       'caption': 'Gardens'},
#      {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/146k/145505/130980773/145505_11832726_IMG_30_0000_max_476x317.jpeg',
#       'url': '146k/145505/130980773/145505_11832726_IMG_30_0000.jpeg',
#       'caption': 'Front'},
#      {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/146k/145505/130980773/145505_11832726_IMG_31_0000_max_476x317.jpeg',
#       'url': '146k/145505/130980773/145505_11832726_IMG_31_0000.jpeg',
#       'caption': 'View'},
#      {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/146k/145505/130980773/145505_11832726_IMG_32_0000_max_476x317.jpeg',
#       'url': '146k/145505/130980773/145505_11832726_IMG_32_0000.jpeg',
#       'caption': 'Gardens'}],
#     'mainImageSrc': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/146k/145505/130980773/145505_11832726_IMG_01_0000_max_476x317.jpeg',
#     'mainMapImageSrc': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/146k/145505/130980773/145505_11832726_IMG_01_0000_max_296x197.jpeg'},
#    'propertySubType': 'Detached',
#    'listingUpdate': {'listingUpdateReason': 'new',
#     'listingUpdateDate': '2023-01-23T14:59:06Z'},
#    'premiumListing': True,
#    'featuredProperty': False,
#    'price': {'amount': 2250000,
#     'frequency': 'not specified',
#     'currencyCode': 'GBP',
#     'displayPrices': [{'displayPrice': '£2,250,000',
#       'displayPriceQualifier': 'Offers in Excess of'}]},
#    'customer': {'branchId': 145505,
#     'brandPlusLogoURI': '/146k/145505/branch_rmchoice_logo_145505_0000.jpeg',
#     'contactTelephone': '0161 524 2355',
#     'branchDisplayName': 'Sell Well, Worsley',
#     'branchName': 'Worsley',
#     'brandTradingName': 'Sell Well',
#     'branchLandingPageUrl': '/estate-agents/agent/Sell-Well/Worsley-145505.html',
#     'development': False,
#     'showReducedProperties': True,
#     'commercial': False,
#     'showOnMap': True,
#     'enhancedListing': False,
#     'developmentContent': None,
#     'buildToRent': False,
#     'buildToRentBenefits': [],
#     'brandPlusLogoUrl': 'https://media.rightmove.co.uk:443/dir/146k/145505/branch_rmchoice_logo_145505_0000_max_100x50.jpeg'},
#    'distance': None,
#    'transactionType': 'buy',
#    'productLabel': {'productLabelText': 'Premium Listing',
#     'spotlightLabel': False},
#    'commercial': False,
#    'development': False,
#    'residential': True,
#    'students': False,
#    'auction': False,
#    'feesApply': False,
#    'feesApplyText': None,
#    'displaySize': '',
#    'showOnMap': True,
#    'propertyUrl': '/properties/130980773#/?channel=RES_BUY',
#    'contactUrl': '/property-for-sale/contactBranch.html?propertyId=130980773',
#    'staticMapUrl': None,
#    'channel': 'BUY',
#    'firstVisibleDate': '2023-01-23T14:53:56Z',
#    'keywords': [],
#    'keywordMatchType': 'no_keyword',
#    'saved': False,
#    'hidden': False,
#    'onlineViewingsAvailable': False,
#    'lozengeModel': {'matchingLozenges': []},
#    'hasBrandPlus': True,
#    'displayStatus': '',
#    'enquiredTimestamp': None,
#    'isRecent': False,
#    'enhancedListing': False,
#    'addedOrReduced': 'Added on 23/01/2023',
#    'formattedBranchName': ' by Sell Well, Worsley',
#    'formattedDistance': '',
#    'heading': '',
#    'propertyTypeFullDescription': '6 bedroom detached house for sale'},
#   {'id': 131271491,
#    'bedrooms': 30,
#    'bathrooms': 18,
#    'numberOfImages': 24,
#    'numberOfFloorplans': 2,
#    'numberOfVirtualTours': 4,
#    'summary': 'Mr Investa are pleased to present this impressive and substantial investment opportunity to acquire 18 units within a popular and consistently fully occupied development producing £117,000 per annum amongst 1 bedroom and 2 bedroom well proportioned apartments. Option to split the 18 units into sm...',
#    'displayAddress': 'Little Moss Court, 1 Little Moss Lane, Clifton, Manchester',
#    'countryCode': 'GB',
#    'location': {'latitude': 53.521229, 'longitude': -2.336485},
#    'propertyImages': {'images': [{'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/235k/234143/131271491/234143_MSN-22622749_IMG_00_0000_max_476x317.jpeg',
#       'url': '235k/234143/131271491/234143_MSN-22622749_IMG_00_0000.jpeg',
#       'caption': 'Little Moss Court'},
#      {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/235k/234143/131271491/234143_MSN-22622749_IMG_01_0000_max_476x317.jpeg',
#       'url': '235k/234143/131271491/234143_MSN-22622749_IMG_01_0000.jpeg',
#       'caption': 'Little Moss Court'},
#      {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/235k/234143/131271491/234143_MSN-22622749_IMG_02_0000_max_476x317.jpeg',
#       'url': '235k/234143/131271491/234143_MSN-22622749_IMG_02_0000.jpeg',
#       'caption': 'Little Moss Court'},
#      {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/235k/234143/131271491/234143_MSN-22622749_IMG_03_0000_max_476x317.jpeg',
#       'url': '235k/234143/131271491/234143_MSN-22622749_IMG_03_0000.jpeg',
#       'caption': 'Little Moss Court'},
#      {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/235k/234143/131271491/234143_MSN-22622749_IMG_04_0000_max_476x317.jpeg',
#       'url': '235k/234143/131271491/234143_MSN-22622749_IMG_04_0000.jpeg',
#       'caption': '2 bed'},
#      {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/235k/234143/131271491/234143_MSN-22622749_IMG_05_0000_max_476x317.jpeg',
#       'url': '235k/234143/131271491/234143_MSN-22622749_IMG_05_0000.jpeg',
#       'caption': '2 bed'},
#      {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/235k/234143/131271491/234143_MSN-22622749_IMG_06_0000_max_476x317.jpeg',
#       'url': '235k/234143/131271491/234143_MSN-22622749_IMG_06_0000.jpeg',
#       'caption': '2 bed'},
#      {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/235k/234143/131271491/234143_MSN-22622749_IMG_07_0000_max_476x317.jpeg',
#       'url': '235k/234143/131271491/234143_MSN-22622749_IMG_07_0000.jpeg',
#       'caption': '2 bed'},
#      {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/235k/234143/131271491/234143_MSN-22622749_IMG_08_0000_max_476x317.jpeg',
#       'url': '235k/234143/131271491/234143_MSN-22622749_IMG_08_0000.jpeg',
#       'caption': '2 bed'},
#      {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/235k/234143/131271491/234143_MSN-22622749_IMG_09_0000_max_476x317.jpeg',
#       'url': '235k/234143/131271491/234143_MSN-22622749_IMG_09_0000.jpeg',
#       'caption': '2 bed'},
#      {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/235k/234143/131271491/234143_MSN-22622749_IMG_10_0000_max_476x317.jpeg',
#       'url': '235k/234143/131271491/234143_MSN-22622749_IMG_10_0000.jpeg',
#       'caption': '2 bed'},
#      {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/235k/234143/131271491/234143_MSN-22622749_IMG_11_0000_max_476x317.jpeg',
#       'url': '235k/234143/131271491/234143_MSN-22622749_IMG_11_0000.jpeg',
#       'caption': '2 bed'},
#      {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/235k/234143/131271491/234143_MSN-22622749_IMG_12_0000_max_476x317.jpeg',
#       'url': '235k/234143/131271491/234143_MSN-22622749_IMG_12_0000.jpeg',
#       'caption': '2 bed'},
#      {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/235k/234143/131271491/234143_MSN-22622749_IMG_13_0000_max_476x317.jpeg',
#       'url': '235k/234143/131271491/234143_MSN-22622749_IMG_13_0000.jpeg',
#       'caption': '2 bed'},
#      {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/235k/234143/131271491/234143_MSN-22622749_IMG_14_0000_max_476x317.jpeg',
#       'url': '235k/234143/131271491/234143_MSN-22622749_IMG_14_0000.jpeg',
#       'caption': '1 bed'},
#      {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/235k/234143/131271491/234143_MSN-22622749_IMG_15_0000_max_476x317.jpeg',
#       'url': '235k/234143/131271491/234143_MSN-22622749_IMG_15_0000.jpeg',
#       'caption': '1 bed'},
#      {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/235k/234143/131271491/234143_MSN-22622749_IMG_16_0000_max_476x317.jpeg',
#       'url': '235k/234143/131271491/234143_MSN-22622749_IMG_16_0000.jpeg',
#       'caption': '1 bed'},
#      {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/235k/234143/131271491/234143_MSN-22622749_IMG_17_0000_max_476x317.jpeg',
#       'url': '235k/234143/131271491/234143_MSN-22622749_IMG_17_0000.jpeg',
#       'caption': '1 bed'},
#      {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/235k/234143/131271491/234143_MSN-22622749_IMG_18_0000_max_476x317.jpeg',
#       'url': '235k/234143/131271491/234143_MSN-22622749_IMG_18_0000.jpeg',
#       'caption': '1 bed'},
#      {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/235k/234143/131271491/234143_MSN-22622749_IMG_19_0000_max_476x317.jpeg',
#       'url': '235k/234143/131271491/234143_MSN-22622749_IMG_19_0000.jpeg',
#       'caption': '1 bed'},
#      {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/235k/234143/131271491/234143_MSN-22622749_IMG_20_0000_max_476x317.jpeg',
#       'url': '235k/234143/131271491/234143_MSN-22622749_IMG_20_0000.jpeg',
#       'caption': '1 bed'},
#      {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/235k/234143/131271491/234143_MSN-22622749_IMG_21_0000_max_476x317.jpeg',
#       'url': '235k/234143/131271491/234143_MSN-22622749_IMG_21_0000.jpeg',
#       'caption': 'Little Moss Court'},
#      {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/235k/234143/131271491/234143_MSN-22622749_IMG_22_0000_max_476x317.jpeg',
#       'url': '235k/234143/131271491/234143_MSN-22622749_IMG_22_0000.jpeg',
#       'caption': 'Little Moss Court'},
#      {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/235k/234143/131271491/234143_MSN-22622749_IMG_23_0000_max_476x317.jpeg',
#       'url': '235k/234143/131271491/234143_MSN-22622749_IMG_23_0000.jpeg',
#       'caption': 'Little Moss Court'}],
#     'mainImageSrc': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/235k/234143/131271491/234143_MSN-22622749_IMG_00_0000_max_476x317.jpeg',
#     'mainMapImageSrc': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/235k/234143/131271491/234143_MSN-22622749_IMG_00_0000_max_296x197.jpeg'},
#    'propertySubType': 'Flat',
#    'listingUpdate': {'listingUpdateReason': 'new',
#     'listingUpdateDate': '2023-01-20T15:23:02Z'},
#    'premiumListing': False,
#    'featuredProperty': False,
#    'price': {'amount': 2190000,
#     'frequency': 'not specified',
#     'currencyCode': 'GBP',
#     'displayPrices': [{'displayPrice': '£2,190,000',
#       'displayPriceQualifier': ''}]},
#    'customer': {'branchId': 234143,
#     'brandPlusLogoURI': '/235k/234143/branch_rmchoice_logo_234143_0001.jpeg',
#     'contactTelephone': '01621 731606',
#     'branchDisplayName': 'Mr Investa Ltd, Salford',
#     'branchName': 'Salford',
#     'brandTradingName': 'Mr Investa Ltd',
#     'branchLandingPageUrl': '/estate-agents/agent/Mr-Investa-Ltd/Salford-234143.html',
#     'development': False,
#     'showReducedProperties': True,
#     'commercial': False,
#     'showOnMap': True,
#     'enhancedListing': False,
#     'developmentContent': None,
#     'buildToRent': False,
#     'buildToRentBenefits': [],
#     'brandPlusLogoUrl': 'https://media.rightmove.co.uk:443/dir/235k/234143/branch_rmchoice_logo_234143_0001_max_100x50.jpeg'},
#    'distance': None,
#    'transactionType': 'buy',
#    'productLabel': {'productLabelText': '', 'spotlightLabel': False},
#    'commercial': False,
#    'development': False,
#    'residential': True,
#    'students': False,
#    'auction': False,
#    'feesApply': False,
#    'feesApplyText': None,
#    'displaySize': '9,300 sq. ft.',
#    'showOnMap': True,
#    'propertyUrl': '/properties/131271491#/?channel=RES_BUY',
#    'contactUrl': '/property-for-sale/contactBranch.html?propertyId=131271491',
#    'staticMapUrl': None,
#    'channel': 'BUY',
#    'firstVisibleDate': '2023-01-31T17:55:13Z',
#    'keywords': [],
#    'keywordMatchType': 'no_keyword',
#    'saved': False,
#    'hidden': False,
#    'onlineViewingsAvailable': False,
#    'lozengeModel': {'matchingLozenges': []},
#    'hasBrandPlus': True,
#    'displayStatus': '',
#    'enquiredTimestamp': None,
#    'isRecent': False,
#    'enhancedListing': False,
#    'addedOrReduced': 'Added on 20/01/2023',
#    'formattedBranchName': ' by Mr Investa Ltd, Salford',
#    'formattedDistance': '',
#    'heading': '',
#    'propertyTypeFullDescription': '30 bedroom flat for sale'},
#   {'id': 132156476,
#    'bedrooms': 4,
#    'bathrooms': 2,
#    'numberOfImages': 23,
#    'numberOfFloorplans': 1,
#    'numberOfVirtualTours': 1,
#    'summary': 'Best In class triplex apartment, in the highly exclusive Beetham Tower.',
#    'displayAddress': 'Beetham Tower, 301 Deansgate, Manchester, M3',
#    'countryCode': 'GB',
#    'location': {'latitude': 53.475433, 'longitude': -2.250546},
#    'propertyImages': {'images': [{'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/202k/201614/132156476/201614_MNS200002_IMG_00_0000_max_476x317.jpeg',
#       'url': '202k/201614/132156476/201614_MNS200002_IMG_00_0000.jpeg',
#       'caption': 'External'},
#      {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/202k/201614/132156476/201614_MNS200002_IMG_01_0000_max_476x317.jpeg',
#       'url': '202k/201614/132156476/201614_MNS200002_IMG_01_0000.jpeg',
#       'caption': 'Living Area'},
#      {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/202k/201614/132156476/201614_MNS200002_IMG_02_0000_max_476x317.jpeg',
#       'url': '202k/201614/132156476/201614_MNS200002_IMG_02_0000.jpeg',
#       'caption': 'Kitchen &amp; Dining'},
#      {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/202k/201614/132156476/201614_MNS200002_IMG_03_0000_max_476x317.jpeg',
#       'url': '202k/201614/132156476/201614_MNS200002_IMG_03_0000.jpeg',
#       'caption': 'Hallway'},
#      {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/202k/201614/132156476/201614_MNS200002_IMG_04_0000_max_476x317.jpeg',
#       'url': '202k/201614/132156476/201614_MNS200002_IMG_04_0000.jpeg',
#       'caption': 'Kitchen &amp; Dining'},
#      {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/202k/201614/132156476/201614_MNS200002_IMG_05_0000_max_476x317.jpeg',
#       'url': '202k/201614/132156476/201614_MNS200002_IMG_05_0000.jpeg',
#       'caption': 'Kitchen &amp; Dining'},
#      {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/202k/201614/132156476/201614_MNS200002_IMG_06_0000_max_476x317.jpeg',
#       'url': '202k/201614/132156476/201614_MNS200002_IMG_06_0000.jpeg',
#       'caption': 'Hallway'},
#      {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/202k/201614/132156476/201614_MNS200002_IMG_07_0000_max_476x317.jpeg',
#       'url': '202k/201614/132156476/201614_MNS200002_IMG_07_0000.jpeg',
#       'caption': 'Bedroom One'},
#      {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/202k/201614/132156476/201614_MNS200002_IMG_08_0000_max_476x317.jpeg',
#       'url': '202k/201614/132156476/201614_MNS200002_IMG_08_0000.jpeg',
#       'caption': 'City Centre Views'},
#      {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/202k/201614/132156476/201614_MNS200002_IMG_09_0000_max_476x317.jpeg',
#       'url': '202k/201614/132156476/201614_MNS200002_IMG_09_0000.jpeg',
#       'caption': 'Bathroom'},
#      {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/202k/201614/132156476/201614_MNS200002_IMG_10_0000_max_476x317.jpeg',
#       'url': '202k/201614/132156476/201614_MNS200002_IMG_10_0000.jpeg',
#       'caption': 'Bathroom'},
#      {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/202k/201614/132156476/201614_MNS200002_IMG_11_0000_max_476x317.jpeg',
#       'url': '202k/201614/132156476/201614_MNS200002_IMG_11_0000.jpeg',
#       'caption': 'Living Area'},
#      {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/202k/201614/132156476/201614_MNS200002_IMG_12_0000_max_476x317.jpeg',
#       'url': '202k/201614/132156476/201614_MNS200002_IMG_12_0000.jpeg',
#       'caption': 'Balcony'},
#      {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/202k/201614/132156476/201614_MNS200002_IMG_13_0000_max_476x317.jpeg',
#       'url': '202k/201614/132156476/201614_MNS200002_IMG_13_0000.jpeg',
#       'caption': 'Bedroom Four'},
#      {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/202k/201614/132156476/201614_MNS200002_IMG_14_0000_max_476x317.jpeg',
#       'url': '202k/201614/132156476/201614_MNS200002_IMG_14_0000.jpeg',
#       'caption': 'Dressing Room'},
# ...
#      'url': '/property-for-sale/Manchester/terraced.html',
#      'noFollow': False},
#     {'text': 'Bungalows for sale in Manchester',
#      'url': '/property-for-sale/Manchester/bungalows.html',
#      'noFollow': False},
#     {'text': 'Property for auction in Manchester',
#      'url': '/property-for-sale/Manchester/auction.html',
#      'noFollow': False},
#     {'text': 'Shared ownership properties for sale in Manchester',
#      'url': '/property-for-sale/Manchester/shared-ownership.html',
#      'noFollow': False},
#     {'text': 'Retirement properties for sale in Manchester',
#      'url': '/property-for-sale/Manchester/retirement.html',
#      'noFollow': False},
#     {'text': 'Commercial properties for sale in Manchester',
#      'url': '/commercial-property-for-sale/Manchester.html',
#      'noFollow': False},
#     {'text': 'New homes for sale in Manchester',
#      'url': '/new-homes-for-sale/Manchester.html',
#      'noFollow': False}],
#    'headingLink': None},
#   'relatedRegionsSearches': None,
#   'channelSwitchLink': {'heading': 'Channel Switch',
#    'subHeading': None,
#    'model': [{'text': 'See properties to rent in Manchester',
#      'url': '/property-to-rent/Manchester.html',
#      'noFollow': False}],
#    'headingLink': None},
#   'relatedStudentLinks': None,
#   'branchMPU': None,
#   'countryGuideMPU': None,
#   'suggestedLinks': {'heading': 'Suggested Links',
#    'subHeading': None,
#    'model': [{'text': 'Estate agents in Manchester',
#      'url': '/estate-agents/Manchester.html',
#      'noFollow': False}],
#    'headingLink': None}},
#  'seoModel': {'canonicalUrl': 'https://www.rightmove.co.uk/property-for-sale/Manchester.html',
#   'metaRobots': ''},
#  'mapViewUrl': '/property-for-sale/map.html?keywords=&sortType=2&viewType=MAP&channel=BUY&index=0&radius=0.0&locationIdentifier=REGION%5E904',
#  'legacyUrl': '/property-for-sale/find.html?keywords=&sortType=2&viewType=LIST&channel=BUY&index=0&radius=0.0&locationIdentifier=REGION%5E904',
#  'listViewUrl': '/property-for-sale/find.html?keywords=&sortType=2&viewType=LIST&channel=BUY&index=0&radius=0.0&locationIdentifier=REGION%5E904',
#  'pageTitle': 'Properties For Sale in Manchester | Rightmove',
#  'metaDescription': "Flats & Houses For Sale in Manchester - Find properties with Rightmove - the UK's largest selection of properties.",
#  'recentSearchModel': {'linkDisplayText': 'Manchester',
#   'titleDisplayText': 'For Sale – Flats & Houses',
#   'searchCriteriaMobile': '<h3>Manchester, for sale, </h3><p>All properties</p>',
#   'createDate': 1678825819347,
#   'locationIdentifierAndSearchType': 'REGION^904_SALE'},
#  'maxCardsPerPage': 25,
#  'countryCode': 'gb',
#  'countryId': -1,
#  'currencyCodeOptions': [{'value': 'GBP', 'description': '£'},
#   {'value': 'EUR', 'description': '€'},
#   {'value': 'USD', 'description': 'USD $'},
#   {'value': 'NZD', 'description': 'NZD $'},
#   {'value': 'AUD', 'description': 'AUD $'},
#   {'value': 'SEK', 'description': 'SEK'},
#   {'value': 'CHF', 'description': 'CHF'}],
#  'areaSizeUnitOptions': [{'value': 'sqft',
#    'description': 'Square Feet',
#    'abbreviation': 'sq. ft.'},
#   {'value': 'sqm', 'description': 'Square Metres', 'abbreviation': 'sq. m.'},
#   {'value': 'acres', 'description': 'Acres', 'abbreviation': 'ac.'},
#   {'value': 'hectares', 'description': 'Hectares', 'abbreviation': 'ha.'}],
#  'sizeOptions': [{'value': '10', 'description': '10', 'abbreviation': '10'},
#   {'value': '50', 'description': '50', 'abbreviation': '50'},
#   {'value': '100', 'description': '100', 'abbreviation': '100'},
#   {'value': '250', 'description': '250', 'abbreviation': '250'},
#   {'value': '500', 'description': '500', 'abbreviation': '500'},
#   {'value': '1000', 'description': '1,000', 'abbreviation': '1K'},
#   {'value': '1500', 'description': '1,500', 'abbreviation': '1.5K'},
#   {'value': '2500', 'description': '2,500', 'abbreviation': '2.5K'},
#   {'value': '5000', 'description': '5,000', 'abbreviation': '5K'},
#   {'value': '7500', 'description': '7,500', 'abbreviation': '7.5K'},
#   {'value': '10000', 'description': '10,000', 'abbreviation': '10K'},
#   {'value': '15000', 'description': '15,000', 'abbreviation': '15K'},
#   {'value': '25000', 'description': '25,000', 'abbreviation': '25K'},
#   {'value': '50000', 'description': '50,000', 'abbreviation': '50K'},
#   {'value': '75000', 'description': '75,000', 'abbreviation': '75K'},
#   {'value': '100000', 'description': '100,000', 'abbreviation': '100K'},
#   {'value': '200000', 'description': '200,000', 'abbreviation': '200K'},
#   {'value': '500000', 'description': '500,000', 'abbreviation': '500K'}],
#  'priceTypeOptions': [{'value': 'ppu',
#    'description': 'Price per unit',
#    'abbreviation': 'PPU'},
#   {'value': 'pcm',
#    'description': 'Price per calendar month',
#    'abbreviation': 'PCM'}],
#  'showFeaturedAgent': True,
#  'showNewDrawASearch': True,
#  'commercialChannel': False,
#  'disambiguationPagePath': 'search.html',
#  'dfpModel': {'sidebarSlots': [{'id': 'searchSidebar-mpuSlot-1',
#     'adUnitPath': '/5029762/Rightmove_Property_Web/Property_Results_Sidebar/MPU1',
#     'sizes': [[300, 250]],
#     'mappings': []}],
#   'targeting': [{'key': 'CT', 'value': 'property-for-sale'}]},
#  'noResultsModel': {'suggestionPods': [], 'intelligentSuggestion': None},
#  'urlPath': '/property-for-sale/find.html',
#  'tileGeometry': None,
#  'comscore': 'pageview_candidate',
#  'cookiePolicies': {'functional': False,
#   'targeting': False,
#   'strictly necessary': True},
#  'formattedExchangeRateDate': '',
#  'authenticated': False,
#  'applicationProperties': {'media.server.host': 'https://media.rightmove.co.uk:443',
#   'location.product.web.server.host': '//product.rightmove.co.uk',
#   'location.product.web.server.port': '80',
#   'publicsite.server.host': '//www.rightmove.co.uk',
#   'publicsite.server.port': '80',
#   'location.search.server.host': 'https://los.rightmove.co.uk',
#   'location.search.server.port': '80',
#   'my.rightmove.web.server.host': 'https://my.rightmove.co.uk',
#   'my.rightmove.web.server.port': '443',
#   'analytics.typeform.url': 'https://s3-eu-west-1.amazonaws.com/share.typeform.com/share.js',
#   'clickstream.enabled': True,
#   'gtm.enabled': True,
#   'gtm.id': 'GTM-MTLF4W9',
#   'gtm.auth': 'g2ndo_352oWlGwJG7HHfyw',
#   'gtm.preview': 'env-7',
#   'comscore.enabled': True,
#   'info.build.version': '@version@',
#   'metadata.service.url': 'https://rightmoveanalytics.co.uk',
#   'sidebar.mpu.adUnitTimeout': '60000',
#   'sidebar.mpu.adUnitPath': '/5029762/Rightmove_Property_Web/Property_Results_Sidebar/MPU1',
#   'dfp.interstitial1.adUnitPath': '/5029762/Rightmove_Property_Web/PropertyWebInterstitial/Interstitial1',
#   'dfp.interstitial2.adUnitPath': '/5029762/Rightmove_Property_Web/PropertyWebInterstitial/Interstitial2',
#   'dfp.interstitial3.adUnitPath': '/5029762/Rightmove_Property_Web/PropertyWebInterstitial/Interstitial3',
#   'dfp.overseas.interstitial1.adUnitPath': '/5029762/Rightmove_Overseas/OverseasPropertyWebInterstitial/Interstitial1',
#   'dfp.overseas.interstitial2.adUnitPath': '/5029762/Rightmove_Overseas/OverseasPropertyWebInterstitial/Interstitial2',
#   'dfp.overseas.interstitial3.adUnitPath': '/5029762/Rightmove_Overseas/OverseasPropertyWebInterstitial/Interstitial3',
#   'dfp.sold-by-me.interstitial.adUnitPath': '/5029762/Rightmove_Property_Web/Sold_by_me',
#   'dfp.sold-by-me.interstitial.commercial-sales.adUnitPath': '/5029762/Rightmove_Property_Web/UK_Commercial_Sales_SearchMPU',
#   'dfp.sold-by-me.interstitial.commercial-lettings.adUnitPath': '/5029762/Rightmove_Property_Web/UK_Commercial_Lettings_SearchMPU',
#   'dfp.sidebar.uk-credit-check-sponsorship.adUnitPath': '/5029762/Rightmove_Property_Web/UK_Sponsorship_Text-link_Search-Results',
#   'optimize.map.pins': True,
#   'rightmovePlusLandingPageUrl': 'https://rmplusportal.rightmove.co.uk',
#   'seo.global.consumerFooter.url': 'http://seo.preferred.h2.prod.rightmove.com/global/consumer-footer',
#   'seo.global.consumerHeader.url': 'http://seo.preferred.h2.prod.rightmove.com/global/consumer-nav/assist',
#   'recaptchaEnabled': True,
#   'recaptchaSiteKey': '6LeZmXUUAAAAACr8BTPYPeJhRTJzH1UCv7d5O7_X',
#   'labsHostname': 'labs.rightmove.co.uk'},
#  'termsOfUse': 'This Application Programming Interface (API) is for the use of Rightmove Group Limited only. No other individual or business may link to, or make use of, this API without the express written permission of Rightmove’s Legal Team. Any unauthorised use of this API will constitute a breach of Rightmove’s Terms of Use, available at https://www.rightmove.co.uk/this-site/terms-of-use.html, and Rightmove will enforce its rights to the fullest extent permitted by law.',
#  'location': {'id': 904,
#   'displayName': 'Manchester, Greater Manchester',
#   'shortDisplayName': 'Manchester',
#   'locationType': 'REGION',
#   'listingCurrency': 'GBP'},
#  'locationBranchSearchPath': None,
#  'featureSwitchStateForUser': {'individualFeatureSwitchStates': [{'label': 'PropertyWebFeatures.COLLAPSE_PROPERTY_LABS_ENABLED',
#     'state': 'on',
#     'shouldLog': False},
#    {'label': 'PropertyWebFeatures.LOAD_GEO_EDGE_SCRIPT',
#     'state': 'on',
#     'shouldLog': False},
#    {'label': 'CookieBarSwitches.SHOW_NON_PERSONALIZED_ADS_INITIALLY',
#     'state': 'on',
#     'shouldLog': False},
#    {'label': 'PropertyWebFeatures.BUYING_SCHEMES_ENABLED',
#     'state': 'on',
#     'shouldLog': False},
#    {'label': 'CookieBarSwitches.LOAD_COMSCORE',
#     'state': 'off',
#     'shouldLog': True},
#    {'label': 'CentralisedComponentsSwitches.GLOBAL_CONSUMER_FOOTER_ENABLED',
#     'state': 'on',
#     'shouldLog': False},
#    {'label': 'PropertyWebFeatures.COLLAPSE_PROPERTY_ENABLED',
#     'state': 'on',
#     'shouldLog': False},
#    {'label': 'PropertyWebFeatures.AFFORDABLE_BUYING_SCHEMES_ENABLED',
#     'state': 'on',
#     'shouldLog': False},
#    {'label': 'CommercialPALSwitches.COMMERCIAL_PAL_ENABLED',
#     'state': 'on',
#     'shouldLog': False},
#    {'label': 'SharedConsumerFeatures.CONSUMER_SURVEY_ENABLED',
#     'state': 'off',
#     'shouldLog': False},
#    {'label': 'PropertyWebFeatures.PROPERTY_DETAILS_URL_MIGRATION_COMMERCIAL_LETTING_ENABLED',
#     'state': 'off',
#     'shouldLog': False},
#    {'label': 'PropertyWebFeatures.PROPERTY_DETAILS_URL_MIGRATION_COMMERCIAL_RESALE_ENABLED',
#     'state': 'off',
#     'shouldLog': False},
#    {'label': 'PropertyWebFeatures.FEATURED_CUSTOMER_PREVIOUS_SEARCHES_ENABLED',
#     'state': 'on',
#     'shouldLog': False},
#    {'label': 'PropertyWebFeatures.COMMERCIAL_KEYWORD_SEARCH',
#     'state': 'on',
#     'shouldLog': False},
#    {'label': 'GoogleTagManagerSwitch.GTM_THIRD_PARTY_TAG_SWITCH',
#     'state': 'on',
#     'shouldLog': True},
#    {'label': 'GlobalSwitches.SHOW_RM_ASSISTANT_BUTTON_PVW',
#     'state': 'on',
#     'shouldLog': False},
#    {'label': 'DrawASearchFeatures.LABS_DRAW_A_SEARCH_ENABLED',
#     'state': 'on',
#     'shouldLog': False},
#    {'label': 'PropertyWebFeatures.HIDE_FEEDBACK_CALL_ENABLED',
#     'state': 'on',
#     'shouldLog': False},
#    {'label': 'PropertyWebFeatures.SHOW_SIDEBAR_MPU_AD',
#     'state': 'on',
#     'shouldLog': False},
#    {'label': 'PropertyWebFeatures.USE_RM_DATALAYER',
#     'state': 'on',
#     'shouldLog': False},
#    {'label': 'SoldByMeSwitches.SOLD_BY_ME_MULTI_PAGE_SUPPORT_ENABLED',
#     'state': 'on',
#     'shouldLog': False},
#    {'label': 'CookieBarSwitches.ENABLE_ONE_TRUST_COOKIE_SCRIPT',
#     'state': 'on',
#     'shouldLog': True},
#    {'label': 'GlobalSwitches.SHOW_RM_ASSISTANT_BUTTON',
#     'state': 'on',
#     'shouldLog': False},
#    {'label': 'PropertyWebFeatures.SAVED_SEARCH_EXPERIMENT',
#     'state': 'on',
#     'shouldLog': False},
#    {'label': 'PropertyWebFeatures.USE_RM_ASSISTANT_COMPONENT',
#     'state': 'on',
#     'shouldLog': False},
#    {'label': 'PropertyWebFeatures.POPULATE_TCUID_COOKIE',
#     'state': 'on',
#     'shouldLog': False},
#    {'label': 'SoldByMeSwitches.DFP_FALLBACK',
#     'state': 'on',
#     'shouldLog': False},
#    {'label': 'PropertyWebFeatures.OS_INTERSTITIAL_TABLET_SIZE_ENABLED',
#     'state': 'off',
#     'shouldLog': False},
#    {'label': 'CentralisedComponentsSwitches.GLOBAL_CONSUMER_HEADER_ENABLED',
#     'state': 'on',
#     'shouldLog': False},
#    {'label': 'PropertyWebFeatures.SHOW_FEEDBACK_BAR',
#     'state': 'on',
#     'shouldLog': False},
#    {'label': 'DrawASearchCopyMVT', 'state': 'COPY_PRESENT', 'shouldLog': True},
#    {'label': 'PropertyWebFeatures.FEATURED_CUSTOMER_V2_ENABLED',
#     'state': 'on',
#     'shouldLog': False},
#    {'label': 'PropertyWebFeatures.PROPERTY_CARD_UPDATES_ENABLED',
#     'state': 'on',
#     'shouldLog': False},
#    {'label': 'OverseasWebFeatures.SHOW_OVERSEAS_SPECIFIC_FILTERS',
#     'state': 'off',
#     'shouldLog': False},
#    {'label': 'PropertyWebFeatures.SHOW_SUGGESTED_SEARCHES',
#     'state': 'on',
#     'shouldLog': False},
#    {'label': 'PropertyWebFeatures.STAMP_DUTY_LINK_IN_FOOTER_ENABLED',
#     'state': 'on',
#     'shouldLog': False},
#    {'label': 'GdprSwitches.SHOW_CONSENT_MODAL_ENABLED',
#     'state': 'on',
#     'shouldLog': False},
#    {'label': 'PropertyWebFeatures.STUDENT_MUST_HAVE_ENABLED',
#     'state': 'on',
#     'shouldLog': False},
#    {'label': 'OverseasWebFeatures.OVERSEAS_LOS_TYPEAHEAD_ENABLED',
#     'state': 'on',
#     'shouldLog': False},
#    {'label': 'PropertyWebFeatures.SAVE_SEARCH_SUPPORT_MAP_POLYLINE',
#     'state': 'off',
#     'shouldLog': False},
#    {'label': 'DrawASearchFeatures.NEW_DRAW_A_SEARCH_ENABLED',
#     'state': 'on',
#     'shouldLog': False},
#    {'label': 'PropertyWebFeatures.SHOW_UK_CREDIT_CHECK_SPONSORSHIP_AD',
#     'state': 'on',
#     'shouldLog': False},
#    {'label': 'PropertyWebFeatures.MODAL_ENABLED',
#     'state': 'on',
#     'shouldLog': False},
#    {'label': 'CookieBarSwitches.BLOCK_UNKNOWN_COOKIES',
#     'state': 'off',
#     'shouldLog': False},
#    {'label': 'PropertyWebFeatures.SHOW_COVID_BANNER',
#     'state': 'off',
#     'shouldLog': False},
#    {'label': 'SoldByMeSwitches.COMMERCIAL_DFP_FALLBACK',
#     'state': 'on',
#     'shouldLog': False}],
#   'featureUser': {'uniqueIdentifier': '230314S2CVYGS3JVLK52R7CCKV8M8QF4'}},
#  'searchParameters': {'locationIdentifier': 'REGION^904',
#   'numberOfPropertiesPerPage': '24',
#   'radius': '0.0',
#   'sortType': '2',
#   'index': '0',
#   'propertyTypes': [],
#   'viewType': 'LIST',
#   'mustHave': [],
#   'dontShow': [],
#   'furnishTypes': [],
#   'channel': 'BUY',
#   'areaSizeUnit': 'sqft',
#   'currencyCode': 'GBP',
#   'keywords': []},
#  'pagination': {'total': 42,
#   'options': [{'value': '0', 'description': '1'},
#    {'value': '24', 'description': '2'},
#    {'value': '48', 'description': '3'},
#    {'value': '72', 'description': '4'},
#    {'value': '96', 'description': '5'},
#    {'value': '120', 'description': '6'},
#    {'value': '144', 'description': '7'},
#    {'value': '168', 'description': '8'},
#    {'value': '192', 'description': '9'},
#    {'value': '216', 'description': '10'},
#    {'value': '240', 'description': '11'},
#    {'value': '264', 'description': '12'},
#    {'value': '288', 'description': '13'},
#    {'value': '312', 'description': '14'},
#    {'value': '336', 'description': '15'},
#    {'value': '360', 'description': '16'},
#    {'value': '384', 'description': '17'},
#    {'value': '408', 'description': '18'},
#    {'value': '432', 'description': '19'},
#    {'value': '456', 'description': '20'},
#    {'value': '480', 'description': '21'},
#    {'value': '504', 'description': '22'},
#    {'value': '528', 'description': '23'},
#    {'value': '552', 'description': '24'},
#    {'value': '576', 'description': '25'},
#    {'value': '600', 'description': '26'},
#    {'value': '624', 'description': '27'},
#    {'value': '648', 'description': '28'},
#    {'value': '672', 'description': '29'},
#    {'value': '696', 'description': '30'},
#    {'value': '720', 'description': '31'},
#    {'value': '744', 'description': '32'},
#    {'value': '768', 'description': '33'},
#    {'value': '792', 'description': '34'},
#    {'value': '816', 'description': '35'},
#    {'value': '840', 'description': '36'},
#    {'value': '864', 'description': '37'},
#    {'value': '888', 'description': '38'},
#    {'value': '912', 'description': '39'},
#    {'value': '936', 'description': '40'},
#    {'value': '960', 'description': '41'},
#    {'value': '984', 'description': '42'}],
#   'first': '0',
#   'last': '984',
#   'next': '24',
#   'page': '1'}}

# %%
def json_to_df(json):
    df = pd.DataFrame(
        columns=[
            "Summary"
        ]
    )
    for i in range(len(json["properties"])):
        df.loc[i] = [
            json["properties"][i]["summary"],
        ]
    return df

# %%
data = json_to_df(get_json(create_url("manchester")))

# %%
data["Summary"][4]
# Out:
# 'Wow.......Dunelm.........It truly is a hidden gem! Occupying a commanding yet concealed position just off the prestigious Chatsworth Road in Worsley. A simply outstanding detached family home which offers an abundance of space set over four floors. On a quiet no-through road from the moment you e...'

# %%
def create_url_list(
    location,
    min_price="",
    max_price="",
    min_bedrooms="",
    max_bedrooms="",
    min_bathrooms="",
    max_bathrooms="",
    radius="",
    property_type="",
):
    def get_index(i):
        return create_url(
            location,
            min_price,
            max_price,
            min_bedrooms,
            max_bedrooms,
            min_bathrooms,
            max_bathrooms,
            radius,
            property_type,
            index=24 * (i - 1))
    url_list=[]
    threads = 30
    with concurrent.futures.ThreadPoolExecutor(max_workers=threads) as executor:
        executor = executor.map(get_index, range(43))
        for url in executor:
            url_list.append(url)
    return url_list

# %%
def download_jsons(url_list):
    threads = min(30, len(url_list))
    json_list=[]
    with concurrent.futures.ThreadPoolExecutor(max_workers=threads) as executor:
        executor = executor.map(get_json, url_list)
        for json in executor:
            json_list.append(json)
        return json_list

# %%
def create_df(jsons):
    df = pd.DataFrame(
        columns=[
            "Summary"
        ]
    )
    for json in jsons:
        new_df = json_to_df(json)
        df = pd.concat([df, new_df], ignore_index=True, axis=0)
    return df.drop_duplicates()

# %%
def create_table(
    location,
    min_price="",
    max_price="",
    min_bedrooms="",
    max_bedrooms="",
    min_bathrooms="",
    max_bathrooms="",
    radius="",
    property_type="",
):
    return create_df(download_jsons(create_url_list(location,
            min_price,
            max_price,
            min_bedrooms,
            max_bedrooms,
            min_bathrooms,
            max_bathrooms,
            radius,
            property_type)))

# %%
data = create_table("manchester")

# %%
data
# Out:
#                                                 Summary
# 0     NO VENDOR CHAIN! LOCATE ESTATE AGENTS are deli...
# 1     OFF MARKET BUILDINGS AVAILABLE, PRICES FROM £4...
# 2     This exquisite 3 bed duplex apartment situated...
# 3     A beautifully presented block of four apartmen...
# 4     Wow.......Dunelm.........It truly is a hidden ...
# ...                                                 ...
# 1070  Local Blackfriars is a gated community compris...
# 1071  NO ONWARD CHAIN. Looking for a very large thre...
# 1072  SEARCH...SEE...LOVE... this excellent three be...
# 1073  Available with no onward chain is this spaciou...
# 1074  ****UNIQUE INDIVIDUALLY BUILT DETACHED RESIDEN...
#
# [927 rows x 1 columns]

# %%
city_list = ["manchester", "leeds"]

# %%
def create_full_table(city_list):
    df = pd.DataFrame(
        columns=[
            "Summary"
        ]
    )
    for city in city_list:
        new_df = create_table(city)
        df = pd.concat([df, new_df], ignore_index=True, axis=0)
        time.sleep(random.randint(3, 7))
        print(city + " is loaded")
    return df.drop_duplicates()

# %%
create_full_table(city_list)
# Out:
#                                                 Summary
# 0     Apartments with 11.7% price growth forecast in...
# 1     OFF MARKET BUILDINGS AVAILABLE, PRICES FROM £4...
# 2     This exquisite 3 bed duplex apartment situated...
# 3     A beautifully presented block of four apartmen...
# 4     Wow.......Dunelm.........It truly is a hidden ...
# ...                                                 ...
# 1940   A SPACIOUS SIX BEDROOMED TERRACED PROPERTY ON...
# 1941  Strike are pleased to offer this stunning, ful...
# 1942  A deceptively spacious end-terrace property wi...
# 1943  *** Extended detached family home *** Highly s...
# 1944  A RARE & EXCITING OPPORTUNITY! One of a kind t...
#
# [1945 rows x 1 columns]

# %%
city_list_scotland = ["Aberdeen",
    "Dundee",
    "Dunfermline",
    "Edinburgh",
    "Glasgow",
    "Inverness",
    "Perth",
    "Stirling",
]

# %%
scotland = create_full_table(city_list_scotland)

# %%
scotland.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2986 entries, 0 to 3002
# Data columns (total 1 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Summary  2986 non-null   object
# dtypes: object(1)
# memory usage: 46.7+ KB

# %%
scotland.to_csv(r"C:\Users\Lawrence\Desktop\NLP-Project\Scotland_csv", index=False)

# %%
scotland1 = pd.read_csv("scotland_csv")

# %%
scotland1["Summary"][3]
# Out:
# 'Prime residential development opportunity on the former site of Aberdeen Exhibition and Conference Centre in the popular Bridge of Don area.'

# %%
city_list_wales = [
    "Bangor",
    "Cardiff",
    "Newport",
    "St-Asaph",
    "St-Davids",
    "Swansea",
    "Wrexham",
]

# %%
wales = create_full_table(city_list_wales)

# %%
wales
# Out:
#                                                 Summary
# 0     Spacious and modern six bedroom HMO with curre...
# 1     This significant site has been owned by the De...
# 2     *Property Ref - IW0179* ** WATCH OUR VIDEO TOU...
# 3     A rare opportunity to acquire this beautiful s...
# 4     Enjoying a highly sought after location, in th...
# ...                                                 ...
# 2707  A mid terraced property with lawned garden to ...
# 2708  1 Bedroom PURPOSE BUILT first floor flat with ...
# 2709  Situated a short distance from Wrexham town ce...
# 2710  An excellent opportunity to purchase a prime b...
# 2711  Situated to the rear of East Avenue , close to...
#
# [2704 rows x 1 columns]

# %%
wales.to_csv(r"C:\Users\Lawrence\Desktop\NLP-Project\Wales_csv", index=False)

# %%
scotland
# Out:
#                                                 Summary
# 0     SUPERB SHEDDOCKSLEY! Click the Virtual Tour li...
# 1     Exceptional Care Home, Retirement Living and R...
# 2     Spectacular mansion house set on a south facin...
# 3     Prime residential development opportunity on t...
# 4     A magnificent residence set in about 3.47 acre...
# ...                                                 ...
# 2998  A traditional main door period flat in the hea...
# 2999  A deceptively spacious three-bedroom, end-terr...
# 3000  New to the Market. NO ONWARD CHAIN! This Semi-...
# 3001  This traditional one bedroom ground floor flat...
# 3002  ** BUY-TO-LET INVESTMENT - TENANT IN SITU ** A...
#
# [2986 rows x 1 columns]

# %%
len(scotland["Summary"][0].split())
# Out:
# 48

# %%
wales1 = pd.read_csv("wales_csv")

# %%
def number_of_words(city):
    word_count = 0
    for sentence_num in range(len(wales1["Summary"])):
        #print(sentence_num)
        word_count += len(wales1["Summary"][sentence_num].split())
    return word_count

# %%
number_of_words(scotland)
# Out:
# 107328

# %%
scotland1["Summary"][1005]
# Out:
# 'Nestled around the Water of Leith this two bedroom ground floor apartment offers stylish open plan living, kitchen, dining area with private terrace, family bathroom and principal en suite.'

# %%
city_list_england_1 = ["Bath",
"Birmingham",
"Bradford",
"Brighton",
"Bristol",
]

# %%
england_1 = create_full_table(city_list_england_1)
# Out:
# Bath is loaded
# Birmingham is loaded
# Bradford is loaded
# Brighton is loaded
# Bristol is loaded

# %%
england_1.to_csv(r"C:\Users\Lawrence\Desktop\NLP-Project\England_1_csv", index=False)

# %%
england_1_csv = pd.read_csv("England_1_csv")

# %%
england_1_csv
# Out:
#                                                 Summary
# 0     This modern detached bungalow offers well prop...
# 1     A substantial Grade I Listed five storey terra...
# 2     A pre-eminent example of classical Georgian ar...
# 3     Spectacular third floor apartment offering fle...
# 4     Sion Hill Place is an absolute hidden gem of p...
# ...                                                 ...
# 4444  An exceedingly spacious and light filled, 3 do...
# 4445  Matthews Estates are pleased to offer to the o...
# 4446  Situated in Rathbone Close is this three bedro...
# 4447  A delightful 2 bedroom apartment with open pla...
# 4448  "We have loved living on Luckwell Road. It off...
#
# [4449 rows x 1 columns]

# %%
city_list_england_2 = [
    "Cambridge",
    "Canterbury",
    "Carlisle",
    "Chelmsford",
    "Chester",
    "Chichester",
    "Colchester",
    "Coventry",
]

# %%
england_2 = create_full_table(city_list_england_2)
# Out:
# Cambridge is loaded
# Canterbury is loaded
# Carlisle is loaded
# Chelmsford is loaded
# Chester is loaded
# Chichester is loaded
# Colchester is loaded
# Coventry is loaded

# %%
england_2.to_csv(r"C:\Users\Lawrence\Desktop\NLP-Project\England_2_csv", index=False)

# %%
england_2_csv = pd.read_csv("England_2_csv")

# %%
england_2_csv
# Out:
#                                                 Summary
# 0     A substantial and elegant Victorian townhouse ...
# 1     Substantial property with annexe & walled gard...
# 2     Stunning substantial home on popular road in t...
# 3     This multi-award-winning, high specification e...
# 4     Detached mid-century family house in need of r...
# ...                                                 ...
# 4913  Reeds Rains Coventry are pleased to offer with...
# 4914  Viewing is highly recommended for this decepti...
# 4915  Reeds Rains are pleased to offer this THREE BE...
# 4916  *Offers in Excess of £200,000 - £220,000 +* Wo...
# 4917  *** TO BE SOLD WITH TENANT IN SITU - INVESTORS...
#
# [4918 rows x 1 columns]

# %%
city_list_england_3 = [
    "Derby",
    "Doncaster",
    "Durham",
    "Ely",
    "Exeter",
    "Gloucester",
    "Hereford",
    "Hull",
]

# %%
england_3 = create_full_table(city_list_england_3)
# Out:
# Derby is loaded
# Doncaster is loaded
# Durham is loaded
# Ely is loaded
# Exeter is loaded
# Gloucester is loaded
# Hereford is loaded
# Hull is loaded

# %%
england_3.to_csv(r"C:\Users\Lawrence\Desktop\NLP-Project\England_3_csv", index=False)

# %%
england_3_csv = pd.read_csv("England_3_csv")

# %%
england_3_csv
# Out:
#                                                 Summary
# 0     EXCLUSIVE LOCATION & GENEROUS GARDEN PLOT - A ...
# 1     BEAUTIFUL HOME SET IN LARGE GARDENS - Fine 192...
# 2     ***NEW OFFER - Reserve a plot at Stephenson Ga...
# 3     ***NEW OFFER - Reserve a plot at Stephenson Ga...
# 4     OFFERING EXCELLENT POTENTIAL FOR FURTHER REDEV...
# ...                                                 ...
# 5267  Calling all investors, this is the perfect inv...
# 5268  INVITING OFFERS BETWEEN £100,000 TO £110,000 A...
# 5269  ***Guide Price £100,000 - £110,000 plus Reserv...
# 5270  A fantastic two bedroom semi-detached property...
# 5271  This Well Presented End Terrace House Offers T...
#
# [5272 rows x 1 columns]

# %%
city_list_england_4 = [
    "Lancaster",
    "Leeds",
    "Leicester",
    "Lichfield",
    "Lincoln",
    "Liverpool",
    "London",
]

# %%
england_4 = create_full_table(city_list_england_4)
# Out:
# Lancaster is loaded
# Leeds is loaded
# Leicester is loaded
# Lichfield is loaded
# Lincoln is loaded
# Liverpool is loaded
# London is loaded

# %%
england_4.to_csv(r"C:\Users\Lawrence\Desktop\NLP-Project\England_4_csv", index=False)

# %%
england_4_csv = pd.read_csv("England_4_csv")

# %%
england_4_csv
# Out:
#                                                 Summary
# 0     Representing a brilliant investment or first t...
# 1     Built in 1978, this imaginatively designed, co...
# 2     Formerly the coach house for the adjacent coun...
# 3     NO CHAIN ***** EXTENDED TERRACED HOUSE *** 5/6...
# 4     Forming part of the historical and charismatic...
# ...                                                 ...
# 5481  A rarely available seven bedroom detached fami...
# 5482  An exceptionally rare opportunity to deliver t...
# 5483  As you enter Queens Gate Gardens through the o...
# 5484  A five bedroom freehold house spanning at almo...
# 5485  Ref. LOB0767 - This grand, three-bedroom apart...
#
# [5486 rows x 1 columns]

# %%
city_list_england_5 = [
    "Manchester",
    "Milton-Keynes",
    "Newcastle-upon-Tyne",
    "Norwich",
    "Nottingham",
    "Oxford",
    "Peterborough",
    "Plymouth",
    "Portsmouth",
    "Preston",
]

# %%
england_5 = create_full_table(city_list_england_5)
# Out:
# Manchester is loaded
# Milton-Keynes is loaded
# Newcastle-upon-Tyne is loaded
# Norwich is loaded
# Nottingham is loaded
# Oxford is loaded
# Peterborough is loaded
# Plymouth is loaded
# Portsmouth is loaded
# Preston is loaded

# %%
england_5.to_csv(r"C:\Users\Lawrence\Desktop\NLP-Project\England_5_csv", index=False)

# %%
england_5_csv = pd.read_csv("England_5_csv")

# %%
england_5_csv
# Out:
#                                                 Summary
# 0     Residential buy to let opportunity for any inv...
# 1     OFF MARKET BUILDINGS AVAILABLE, PRICES FROM £4...
# 2     This exquisite 3 bed duplex apartment situated...
# 3     Wow.......Dunelm.........It truly is a hidden ...
# 4     A beautifully presented block of four apartmen...
# ...                                                 ...
# 9252  We are pleased to offer to the auction this on...
# 9253  Modern one bedroom first floor apartment boast...
# 9254  **SOLD STC**SIMILAR PROPERTIES REQUIRED** Haze...
# 9255  Ben Rose Estate Agents are pleased to present ...
# 9256  FOR SALE BY AUCTION: Starting Bids £99,950. Te...
#
# [9257 rows x 1 columns]

# %%
city_list_england_6 = [
    "Ripon",
    "Salford",
    "Salisbury",
    "Sheffield",
    "Southampton",
    "Southend-on-Sea",
    "St-Albans",
    "Stoke-on-Trent",
    "Sunderland",
]

# %%
england_6 = create_full_table(city_list_england_6)
# Out:
# Ripon is loaded
# Salford is loaded
# Salisbury is loaded
# Sheffield is loaded
# Southampton is loaded
# Southend-on-Sea is loaded
# St-Albans is loaded
# Stoke-on-Trent is loaded
# Sunderland is loaded

# %%
england_6.to_csv(r"C:\Users\Lawrence\Desktop\NLP-Project\England_6_csv", index=False)

# %%
england_6_csv = pd.read_csv("England_6_csv")

# %%
england_6_csv
# Out:
#                                                 Summary
# 0     Close to local schools ideal for families, Rip...
# 1     A rare development/investment opportunity comp...
# 2     A stunning recently updated detached four-bedr...
# 3     A stunning period family home with a self-cont...
# 4     A building plot overlooking open countryside w...
# ...                                                 ...
# 6288  *FANTASTIC CASH INVESTMENT OPPORTUNITY* CIRCA ...
# 6289  INVESTOR POTENTIAL ONE BEDROOM MID TERRACE HOU...
# 6290  FOR SALE VIA I AM SOLD AUCTION T&C's apply. Th...
# 6291  Freehold House Arranged as Two Flats Vacant Po...
# 6292  Guide Price £4,000 + We offer For Sale via Unc...
#
# [6293 rows x 1 columns]

# %%
city_list_england_7 = [
    "Truro",
    "Wakefield",
    "Wells",
    "Winchester",
    "Wolverhampton",
    "Worcester",
    "York",
]

# %%
england_7 = create_full_table(city_list_england_7)
# Out:
# Truro is loaded
# Wakefield is loaded
# Wells is loaded
# Winchester is loaded
# Wolverhampton is loaded
# Worcester is loaded
# York is loaded

# %%
england_7.to_csv(r"C:\Users\Lawrence\Desktop\NLP-Project\England_7_csv", index=False)

# %%
england_7_csv = pd.read_csv("England_7_csv")

# %%
england_7_csv
